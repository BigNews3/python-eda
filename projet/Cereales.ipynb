# %%
import pandas as pd 
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt 
# %matplotlib inline

# %%
1. General dataset overview

# %%
print('Ce dataset contient des informations sur des céréales pour le petit-déjeuner vendu dans la grande distribution américaine')
print("L'objectif principal de ce dataset est de mettre en avant ce qui fait qu'un paquet de céréale obtient une note qualitative")
# Out:
# Ce dataset contient des informations sur des céréales pour le petit-déjeuner vendu dans la grande distribution américaine
# L'objectif principal de ce dataset est de mettre en avant ce qui fait qu'un paquet de céréale obtient une note qualitative

# %%
db = pd.read_csv('../DATA/cereal.csv')
db.head(10)
# Out:
#                         name mfr type  calories  protein  fat  sodium  fiber  \
# 0                  100% Bran   N    C        70        4    1     130   10.0
# 1          100% Natural Bran   Q    C       120        3    5      15    2.0
# 2                   All-Bran   K    C        70        4    1     260    9.0
# 3  All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# 4             Almond Delight   R    C       110        2    2     200    1.0
# 5    Apple Cinnamon Cheerios   G    C       110        2    2     180    1.5
# 6                Apple Jacks   K    C       110        2    0     125    1.0
# 7                    Basic 4   G    C       130        3    2     210    2.0
# 8                  Bran Chex   R    C        90        2    1     200    4.0
# 9                Bran Flakes   P    C        90        3    0     210    5.0
#
#    carbo  sugars  potass  vitamins  shelf  weight  cups     rating
# ...

# %%
db.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 77 entries, 0 to 76
# Data columns (total 16 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   name      77 non-null     object
#  1   mfr       77 non-null     object
#  2   type      77 non-null     object
#  3   calories  77 non-null     int64
#  4   protein   77 non-null     int64
#  5   fat       77 non-null     int64
#  6   sodium    77 non-null     int64
#  7   fiber     77 non-null     float64
#  8   carbo     77 non-null     float64
#  9   sugars    77 non-null     int64
#  10  potass    77 non-null     int64
#  11  vitamins  77 non-null     int64
#  12  shelf     77 non-null     int64
#  13  weight    77 non-null     float64
#  14  cups      77 non-null     float64
#  15  rating    77 non-null     float64
# dtypes: float64(5), int64(8), object(3)
# memory usage: 9.8+ KB

# %%
db.describe()
# Out:
#          calories    protein        fat      sodium      fiber      carbo  \
# count   77.000000  77.000000  77.000000   77.000000  77.000000  77.000000
# mean   106.883117   2.545455   1.012987  159.675325   2.151948  14.597403
# std     19.484119   1.094790   1.006473   83.832295   2.383364   4.278956
# min     50.000000   1.000000   0.000000    0.000000   0.000000  -1.000000
# 25%    100.000000   2.000000   0.000000  130.000000   1.000000  12.000000
# 50%    110.000000   3.000000   1.000000  180.000000   2.000000  14.000000
# 75%    110.000000   3.000000   2.000000  210.000000   3.000000  17.000000
# max    160.000000   6.000000   5.000000  320.000000  14.000000  23.000000
#
#           sugars      potass    vitamins      shelf     weight       cups  \
# count  77.000000   77.000000   77.000000  77.000000  77.000000  77.000000
# mean    6.922078   96.077922   28.246753   2.207792   1.029610   0.821039
# std     4.444885   71.286813   22.342523   0.832524   0.150477   0.232716
# ...

# %%
print("On peut voir ici que 75% des p")

# %%
print('Sucres')
# Out:
# Sucres

# %%
sns.scatterplot(data=db, x='sugars', y='rating', hue='mfr')
# Out:
# <AxesSubplot:xlabel='sugars', ylabel='rating'>

# %%
sns.lmplot(data=db, x='sugars', y='rating')

# %%
print('On peut voir ici que le taux de sucre a une forte colération avec le rating. Pour obtenir un bon rating il vaut mieux privilégier peu de sucres')
# Out:
# On peut voir ici que le taux de sucre a une forte colération avec le rating. Pour obtenir un bon rating il vaut mieux privilégier peu de sucres

# %%
print('Sodium')
# Out:
# Sodium

# %%
sns.lmplot(data=db,x="sodium",y="rating")

# %%
La corélation est plus faible concernant le taux de sodium, en  revanche on peut voir que la majorité des ratings supérieurs sont trés faibles en sodium

# %%
print('Vitamines')
# Out:
# Vitamines

# %%
sns.scatterplot(data=db,x="vitamins",y="rating")
# Out:
# <AxesSubplot:xlabel='vitamins', ylabel='rating'>

# %%
On peut voir que le taux de vitamines n a quasiment pas d incidences sur le rating

# %%
sns.scatterplot(data=db,x="calories",y="rating", hue='mfr')
# Out:
# <AxesSubplot:xlabel='calories', ylabel='rating'>

# %%
sns.lmplot(data=db, x='calories', y='rating')

# %%
On peut voir que la corélation est trés forte entre le rating et les calories dans le  produit

# %%
sns.catplot(data=db, x='sugars', y='rating', kind='bar')

# %%
sns.boxplot(data=db, x='sugars', y='rating')
# Out:
# <AxesSubplot:xlabel='sugars', ylabel='rating'>

# %%
sns.catplot(data=db, x='calories', y='rating', kind='bar')

# %%
sns.boxplot(data=db, x='calories', y='rating')
# Out:
# <AxesSubplot:xlabel='calories', ylabel='rating'>

# %%
db['mfr'].describe()
# Out:
# count     77
# unique     7
# top        K
# freq      23
# Name: mfr, dtype: object

# %%
sns.catplot(data=db, x='mfr', y='rating',  kind='bar')

# %%
Ce graphique permet de mettre en avant les  ratings moyens par manufactureurs

# %%
sns.catplot(data=db, x='type', y='rating',  kind='bar')

# %%
On peut voir trés nettement que le rating est plus important pour les cérélales de type chaudes

# %%
db_corr = db.iloc[:,-13:]
db_corr.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 77 entries, 0 to 76
# Data columns (total 13 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   calories  77 non-null     int64
#  1   protein   77 non-null     int64
#  2   fat       77 non-null     int64
#  3   sodium    77 non-null     int64
#  4   fiber     77 non-null     float64
#  5   carbo     77 non-null     float64
#  6   sugars    77 non-null     int64
#  7   potass    77 non-null     int64
#  8   vitamins  77 non-null     int64
#  9   shelf     77 non-null     int64
#  10  weight    77 non-null     float64
#  11  cups      77 non-null     float64
#  12  rating    77 non-null     float64
# dtypes: float64(5), int64(8)
# memory usage: 7.9 KB

# %%
corr = db_corr.corr()
f, ax = plt.subplots(figsize=(15, 5))
sns.heatmap(corr, annot=True, ax=ax)
# Out:
# <AxesSubplot:>
